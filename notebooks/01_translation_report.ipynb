# %% [markdown]
# # 01 — Translation Report (Phase B Evaluation)
#
# Notebook consolidado de fechamento do TCC. Lê os summary JSONs das tasks T13/T15-T19/T22 + `validation_results.jsonl` (T20) e renderiza em 12 seções com testes de hipóteses (H1–H8) com correção Holm-Bonferroni.
#
# **Princípio:** "T-x produz, F11 lê" — não recomputa, só renderiza.
#
# **Estado:** PRE-FLIGHT skeleton (estrutura de seções pronta; implementação dos plots/análises pendente até T13 + T20 terminarem).

# %% [markdown]
# ## 0. Headline executiva
# Tabela 1 página com 3 taxas de aprovação separadas.

# %%
# Setup — implementar quando T20 terminar
# import json, pandas as pd
# from pathlib import Path
# from src.evaluation.notebook_helpers import median_with_ci, proportion_with_ci, build_executive_summary
#
# DIR = Path('../results/translation')
# records = [json.loads(l) for l in open(DIR / 'validation_results.jsonl')]
# summaries = {
#     'audit':     json.loads((DIR / 'audit_deepseek_summary.json').read_text()),
#     'intrinsic': json.loads((DIR / 'intrinsic_metrics_summary.json').read_text()),
#     'modifier':  json.loads((DIR / 'modifier_summary.json').read_text()),
#     'duplicate': json.loads((DIR / 'duplicate_stability_summary.json').read_text()),
#     'lexical':   json.loads((DIR / 'lexical_global_summary.json').read_text()),
# }
# build_executive_summary(records, summaries)

# %% [markdown]
# ## 1. Visão geral
# Volume, distribuição BI-RADS, headline = taxa de erro crítico (H8).

# %%
# pendente

# %% [markdown]
# ## 2. Qualidade semântica (T15)
# BERTScore-F1 + chrF++ + cosine + length_ratio main; TER apêndice. **BLEU excluído** (justificativa em §4.2.2 do TCC).

# %%
# pendente

# %% [markdown]
# ## 3. Back-translation (T14.B — caveat amostra ~250)

# %%
# pendente — depende de T14.B + T14.A merge

# %% [markdown]
# ## 4. Structural checks (T16)
# all_structural_pass por dimensão.

# %%
# pendente

# %% [markdown]
# ## 5. Léxico BI-RADS (T17)
# overall_canonical_rate × overall_acceptable_rate, anomalias.

# %%
# pendente

# %% [markdown]
# ## 5b. Morfossintaxe (T18)
# preservation_rate, divergence_breakdown, abstain rate.

# %%
# pendente

# %% [markdown]
# ## 6. Estabilidade operacional (T19)
# **Caveat:** análise observacional de produção, não experimento controlado.

# %%
# pendente

# %% [markdown]
# ## 7. Auditoria DeepSeek (T13)
# C1–C7 distributions + meta-validação (kept vs refuted).

# %%
# pendente — depende de T13 terminar

# %% [markdown]
# ## 7b. Calibração GPT-4o-mini (T13 Step 5)
# Cohen's κ DeepSeek↔GPT por critério; decisão PRIMARY_STABLE/MODERATE/DOWNGRADE.

# %%
# pendente — depende de T13 Step 5 (autorização explícita do user)

# %% [markdown]
# ## 8. Concordância entre fontes (T21)
# κ heatmap das 6 fontes + nota interpretativa + κ por BI-RADS (subsidia H6).

# %%
# pendente — depende de T21

# %% [markdown]
# ## 9. Revisão humana (T22)
# κ humano × LLM auditor; cross-validation has_critical_error_human × LLM.

# %%
# pendente — depende de revisão MQM externa

# %% [markdown]
# ## 10. Análise de erros
# Taxonomia via failure_reasons do T20 — distribuição, top-20 por razão, recomendações.

# %%
# pendente

# %% [markdown]
# ## 11. Composite Score
# Distribuição, faixas (90+, 75-89, <75), referência à tag `composite-score-formula-pre-registered`.

# %%
# pendente

# %% [markdown]
# ## 12. Reproducibility statement
# Auto-gerado: hashes, modelos, parâmetros, custos, tags pré-registradas.

# %%
# pendente
